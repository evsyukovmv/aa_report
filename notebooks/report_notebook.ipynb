# %%
import os
os.environ["JAVA_HOME"] = "/usr/local/opt/openjdk"
os.environ["SPARK_HOME"] = "/usr/local/Cellar/apache-spark/3.3.0/libexec/"

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
spark
# Out:
# 22/08/08 16:31:31 WARN Utils: Your hostname, Mykhailos-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 192.168.31.225 instead (on interface en0)
# 22/08/08 16:31:31 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/08/08 16:31:31 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.31.225:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import os
import json

with open('./config.json', 'r') as f:
    config = json.load(f)

# %% [markdown]
# ### Extract data from CSV file

# %%
taxi_tripdata = spark.read \
    .option('header', True) \
    .option('inferSchema', True) \
    .csv(config['data']['source'], header=True)

taxi_tripdata.show(5, truncate=False, vertical=True)
# Out:
# -RECORD 0------------------------------------
#  VendorID              | 1
#  lpep_pickup_datetime  | 2021-07-01 00:30:52
#  lpep_dropoff_datetime | 2021-07-01 00:35:36
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 74
#  DOLocationID          | 168
#  passenger_count       | 1
#  trip_distance         | 1.2
#  fare_amount           | 6.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 7.3
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 1------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2021-07-01 00:25:36
#  lpep_dropoff_datetime | 2021-07-01 01:01:31
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 116
#  DOLocationID          | 265
#  passenger_count       | 2
#  trip_distance         | 13.69
#  fare_amount           | 42.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 43.3
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 2------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2021-07-01 00:05:58
#  lpep_dropoff_datetime | 2021-07-01 00:12:00
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 97
#  DOLocationID          | 33
#  passenger_count       | 1
#  trip_distance         | 0.95
#  fare_amount           | 6.5
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 2.34
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 10.14
#  payment_type          | 1
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 3------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2021-07-01 00:41:40
#  lpep_dropoff_datetime | 2021-07-01 00:47:23
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 74
#  DOLocationID          | 42
#  passenger_count       | 1
#  trip_distance         | 1.24
#  fare_amount           | 6.5
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 7.8
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 4------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2021-07-01 00:51:32
#  lpep_dropoff_datetime | 2021-07-01 00:58:46
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 42
#  DOLocationID          | 244
#  passenger_count       | 1
#  trip_distance         | 1.1
#  fare_amount           | 7.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 8.3
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# only showing top 5 rows

# %% [markdown]
# ### Map Vendor and Payment Type to string value from the VendorID and payment_type

# %%
from pyspark.sql.functions import col
from itertools import chain
from pyspark.sql.functions import create_map, lit

vendors_dict = { 1: 'Creative Mobile Technologies', 2: 'VeriFone Inc.' }
verndors_mapping_expr = create_map([lit(x) for x in chain(*vendors_dict.items())])

payment_types_dict = { 1: 'Credit card', 2: 'Cash', 3: 'No charge', 4: 'Dispute', 5: 'Unknown', 6: 'Voided trip' }
payment_types_mapping_expr = create_map([lit(x) for x in chain(*payment_types_dict.items())])

report = taxi_tripdata \
    .withColumn('Vendor', verndors_mapping_expr[col('VendorID')]) \
    .withColumn('Payment Type', payment_types_mapping_expr[col('payment_type')])

report.show(5, truncate=False, vertical=True)
# Out:
# -RECORD 0---------------------------------------------
#  VendorID              | 1
#  lpep_pickup_datetime  | 2021-07-01 00:30:52
#  lpep_dropoff_datetime | 2021-07-01 00:35:36
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 74
#  DOLocationID          | 168
#  passenger_count       | 1
#  trip_distance         | 1.2
#  fare_amount           | 6.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 7.3
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Cash
# -RECORD 1---------------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2021-07-01 00:25:36
#  lpep_dropoff_datetime | 2021-07-01 01:01:31
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 116
#  DOLocationID          | 265
#  passenger_count       | 2
#  trip_distance         | 13.69
#  fare_amount           | 42.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 43.3
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | VeriFone Inc.
#  Payment Type          | Cash
# -RECORD 2---------------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2021-07-01 00:05:58
#  lpep_dropoff_datetime | 2021-07-01 00:12:00
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 97
#  DOLocationID          | 33
#  passenger_count       | 1
#  trip_distance         | 0.95
#  fare_amount           | 6.5
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 2.34
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 10.14
#  payment_type          | 1
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | VeriFone Inc.
#  Payment Type          | Credit card
# -RECORD 3---------------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2021-07-01 00:41:40
#  lpep_dropoff_datetime | 2021-07-01 00:47:23
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 74
#  DOLocationID          | 42
#  passenger_count       | 1
#  trip_distance         | 1.24
#  fare_amount           | 6.5
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 7.8
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | VeriFone Inc.
#  Payment Type          | Cash
# -RECORD 4---------------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2021-07-01 00:51:32
#  lpep_dropoff_datetime | 2021-07-01 00:58:46
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 42
#  DOLocationID          | 244
#  passenger_count       | 1
#  trip_distance         | 1.1
#  fare_amount           | 7.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 8.3
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | VeriFone Inc.
#  Payment Type          | Cash
# only showing top 5 rows

# %% [markdown]
# ### Calculate Passanger count per Vendor and Payment Type

# %%
pass_count_per_vendor_payment = report \
    .groupBy('VendorID', 'payment_type').sum('passenger_count') \
    .withColumnRenamed("sum(passenger_count)", 'PCPVP')
pass_count_per_vendor_payment.show()
# Out:
# +--------+------------+-----+
# |VendorID|payment_type|PCPVP|
# +--------+------------+-----+
# |       2|           2|24091|
# |       2|           3|  154|
# |       1|           2| 3546|
# |       1|           1| 5115|
# |       1|           3|  199|
# |       1|           4|   25|
# |       2|           1|33770|
# |       2|           4|   26|
# |       1|           5|    1|
# |    null|        null| null|
# +--------+------------+-----+

# %% [markdown]
# ### Join calulated Passenger count to report

# %%
report = report \
    .join(pass_count_per_vendor_payment, ['VendorID', 'payment_type'])
report.show(5, truncate=False, vertical=True)
# Out:
# -RECORD 0---------------------------------------------
#  VendorID              | 1
#  payment_type          | 2
#  lpep_pickup_datetime  | 2021-07-01 00:30:52
#  lpep_dropoff_datetime | 2021-07-01 00:35:36
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 74
#  DOLocationID          | 168
#  passenger_count       | 1
#  trip_distance         | 1.2
#  fare_amount           | 6.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 7.3
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Cash
#  PCPVP                 | 3546
# -RECORD 1---------------------------------------------
#  VendorID              | 2
#  payment_type          | 2
#  lpep_pickup_datetime  | 2021-07-01 00:25:36
#  lpep_dropoff_datetime | 2021-07-01 01:01:31
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 116
#  DOLocationID          | 265
#  passenger_count       | 2
#  trip_distance         | 13.69
#  fare_amount           | 42.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 43.3
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | VeriFone Inc.
#  Payment Type          | Cash
#  PCPVP                 | 24091
# -RECORD 2---------------------------------------------
#  VendorID              | 2
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-01 00:05:58
#  lpep_dropoff_datetime | 2021-07-01 00:12:00
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 97
#  DOLocationID          | 33
#  passenger_count       | 1
#  trip_distance         | 0.95
#  fare_amount           | 6.5
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 2.34
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 10.14
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | VeriFone Inc.
#  Payment Type          | Credit card
#  PCPVP                 | 33770
# -RECORD 3---------------------------------------------
#  VendorID              | 2
#  payment_type          | 2
#  lpep_pickup_datetime  | 2021-07-01 00:41:40
#  lpep_dropoff_datetime | 2021-07-01 00:47:23
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 74
#  DOLocationID          | 42
#  passenger_count       | 1
#  trip_distance         | 1.24
#  fare_amount           | 6.5
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 7.8
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | VeriFone Inc.
#  Payment Type          | Cash
#  PCPVP                 | 24091
# -RECORD 4---------------------------------------------
#  VendorID              | 2
#  payment_type          | 2
#  lpep_pickup_datetime  | 2021-07-01 00:51:32
#  lpep_dropoff_datetime | 2021-07-01 00:58:46
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 42
#  DOLocationID          | 244
#  passenger_count       | 1
#  trip_distance         | 1.1
#  fare_amount           | 7.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 8.3
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | VeriFone Inc.
#  Payment Type          | Cash
#  PCPVP                 | 24091
# only showing top 5 rows

# %% [markdown]
# ### Calculate Payment Rate for report based on Passenger count and Total amount

# %%
report = report.withColumn('Payment Rate', col('total_amount') / col('PCPVP'))
report.show(5, truncate=False, vertical=True)
# Out:
# -RECORD 0---------------------------------------------
#  VendorID              | 1
#  payment_type          | 2
#  lpep_pickup_datetime  | 2021-07-01 00:30:52
#  lpep_dropoff_datetime | 2021-07-01 00:35:36
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 74
#  DOLocationID          | 168
#  passenger_count       | 1
#  trip_distance         | 1.2
#  fare_amount           | 6.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 7.3
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Cash
#  PCPVP                 | 3546
#  Payment Rate          | 0.0020586576424139877
# -RECORD 1---------------------------------------------
#  VendorID              | 2
#  payment_type          | 2
#  lpep_pickup_datetime  | 2021-07-01 00:25:36
#  lpep_dropoff_datetime | 2021-07-01 01:01:31
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 116
#  DOLocationID          | 265
#  passenger_count       | 2
#  trip_distance         | 13.69
#  fare_amount           | 42.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 43.3
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | VeriFone Inc.
#  Payment Type          | Cash
#  PCPVP                 | 24091
#  Payment Rate          | 0.0017973517081067618
# -RECORD 2---------------------------------------------
#  VendorID              | 2
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-01 00:05:58
#  lpep_dropoff_datetime | 2021-07-01 00:12:00
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 97
#  DOLocationID          | 33
#  passenger_count       | 1
#  trip_distance         | 0.95
#  fare_amount           | 6.5
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 2.34
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 10.14
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | VeriFone Inc.
#  Payment Type          | Credit card
#  PCPVP                 | 33770
#  Payment Rate          | 3.0026650873556413E-4
# -RECORD 3---------------------------------------------
#  VendorID              | 2
#  payment_type          | 2
#  lpep_pickup_datetime  | 2021-07-01 00:41:40
#  lpep_dropoff_datetime | 2021-07-01 00:47:23
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 74
#  DOLocationID          | 42
#  passenger_count       | 1
#  trip_distance         | 1.24
#  fare_amount           | 6.5
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 7.8
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | VeriFone Inc.
#  Payment Type          | Cash
#  PCPVP                 | 24091
#  Payment Rate          | 3.23772363123158E-4
# -RECORD 4---------------------------------------------
#  VendorID              | 2
#  payment_type          | 2
#  lpep_pickup_datetime  | 2021-07-01 00:51:32
#  lpep_dropoff_datetime | 2021-07-01 00:58:46
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 42
#  DOLocationID          | 244
#  passenger_count       | 1
#  trip_distance         | 1.1
#  fare_amount           | 7.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 8.3
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | VeriFone Inc.
#  Payment Type          | Cash
#  PCPVP                 | 24091
#  Payment Rate          | 3.4452700178489896E-4
# only showing top 5 rows

# %% [markdown]
# ### Add Next Payment Rate
# 1. Add Rank number by Payment Rate
# 2. Find next Rank and take Payment Rate value

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import min, rank

windowSpecRank = Window.partitionBy('VendorID', 'payment_type').orderBy('Payment Rate')
windowSpecNextRank = Window.partitionBy('VendorID', 'payment_type').orderBy('payment_rate_rank').rangeBetween(1, Window.unboundedFollowing)

report = report \
    .withColumn('payment_rate_rank', rank().over(windowSpecRank)) \
    .withColumn('Next Payment Rate', min('Payment Rate').over(windowSpecNextRank))

report.show(10, truncate=False, vertical=True)
# Out:
# 22/08/08 16:31:38 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# -RECORD 0---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-01 18:33:14
#  lpep_dropoff_datetime | 2021-07-01 18:44:52
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 35
#  DOLocationID          | 76
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
# -RECORD 1---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-11 08:25:43
#  lpep_dropoff_datetime | 2021-07-11 08:25:51
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 241
#  DOLocationID          | 241
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
# -RECORD 2---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-12 06:08:49
#  lpep_dropoff_datetime | 2021-07-12 06:09:05
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 183
#  DOLocationID          | 183
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 2
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
# -RECORD 3---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-12 09:08:26
#  lpep_dropoff_datetime | 2021-07-12 09:25:59
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 182
#  DOLocationID          | 179
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
# -RECORD 4---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-12 12:47:32
#  lpep_dropoff_datetime | 2021-07-12 12:51:33
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 26
#  DOLocationID          | 26
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
# -RECORD 5---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-14 06:34:18
#  lpep_dropoff_datetime | 2021-07-14 06:35:15
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 182
#  DOLocationID          | 182
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 2
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
# -RECORD 6---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-15 13:22:05
#  lpep_dropoff_datetime | 2021-07-15 13:59:07
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 80
#  DOLocationID          | 22
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
# -RECORD 7---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-19 09:42:33
#  lpep_dropoff_datetime | 2021-07-19 09:47:34
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 26
#  DOLocationID          | 178
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
# -RECORD 8---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-21 11:02:27
#  lpep_dropoff_datetime | 2021-07-21 11:08:50
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 47
#  DOLocationID          | 47
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
# -RECORD 9---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-21 12:44:33
#  lpep_dropoff_datetime | 2021-07-21 12:55:39
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 45
#  DOLocationID          | 137
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
# only showing top 10 rows

# %% [markdown]
# ### Calculate Max Payment Rate by Vendor

# %%
max_payment_reate_per_vendor = report \
    .groupBy('VendorID').max('Payment Rate') \
    .withColumnRenamed("max(Payment Rate)", 'Max Payment Rate')

max_payment_reate_per_vendor.show()
# Out:
# +--------+--------------------+
# |VendorID|    Max Payment Rate|
# +--------+--------------------+
# |       1|               39.55|
# |       2|0.014222978975421973|
# +--------+--------------------+

# %% [markdown]
# ### Join Max Payment Rate to report

# %%
report = report \
    .join(max_payment_reate_per_vendor, 'VendorID')

report.show(10, truncate=False, vertical=True)
# Out:
# -RECORD 0---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-01 18:33:14
#  lpep_dropoff_datetime | 2021-07-01 18:44:52
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 35
#  DOLocationID          | 76
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
# -RECORD 1---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-11 08:25:43
#  lpep_dropoff_datetime | 2021-07-11 08:25:51
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 241
#  DOLocationID          | 241
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
# -RECORD 2---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-12 06:08:49
#  lpep_dropoff_datetime | 2021-07-12 06:09:05
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 183
#  DOLocationID          | 183
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 2
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
# -RECORD 3---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-12 09:08:26
#  lpep_dropoff_datetime | 2021-07-12 09:25:59
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 182
#  DOLocationID          | 179
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
# -RECORD 4---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-12 12:47:32
#  lpep_dropoff_datetime | 2021-07-12 12:51:33
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 26
#  DOLocationID          | 26
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
# -RECORD 5---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-14 06:34:18
#  lpep_dropoff_datetime | 2021-07-14 06:35:15
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 182
#  DOLocationID          | 182
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 2
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
# -RECORD 6---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-15 13:22:05
#  lpep_dropoff_datetime | 2021-07-15 13:59:07
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 80
#  DOLocationID          | 22
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
# -RECORD 7---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-19 09:42:33
#  lpep_dropoff_datetime | 2021-07-19 09:47:34
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 26
#  DOLocationID          | 178
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
# -RECORD 8---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-21 11:02:27
#  lpep_dropoff_datetime | 2021-07-21 11:08:50
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 47
#  DOLocationID          | 47
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
# -RECORD 9---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-21 12:44:33
#  lpep_dropoff_datetime | 2021-07-21 12:55:39
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 45
#  DOLocationID          | 137
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
# only showing top 10 rows

# %% [markdown]
# ### Calculate Percents to Next Payment Rate

# %%
from pyspark.sql.functions import round, concat

report = report.withColumn(
    'Percents to next rate',
    concat(
        round(100 - col('Payment Rate') * 100 / col('Next Payment Rate'), 2),
        lit('%')
    )
)
report.show(15, truncate=False, vertical=True)
# Out:
# -RECORD 0---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-01 18:33:14
#  lpep_dropoff_datetime | 2021-07-01 18:44:52
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 35
#  DOLocationID          | 76
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
#  Percents to next rate | 100.0%
# -RECORD 1---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-11 08:25:43
#  lpep_dropoff_datetime | 2021-07-11 08:25:51
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 241
#  DOLocationID          | 241
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
#  Percents to next rate | 100.0%
# -RECORD 2---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-12 06:08:49
#  lpep_dropoff_datetime | 2021-07-12 06:09:05
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 183
#  DOLocationID          | 183
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 2
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
#  Percents to next rate | 100.0%
# -RECORD 3---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-12 09:08:26
#  lpep_dropoff_datetime | 2021-07-12 09:25:59
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 182
#  DOLocationID          | 179
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
#  Percents to next rate | 100.0%
# -RECORD 4---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-12 12:47:32
#  lpep_dropoff_datetime | 2021-07-12 12:51:33
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 26
#  DOLocationID          | 26
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
#  Percents to next rate | 100.0%
# -RECORD 5---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-14 06:34:18
#  lpep_dropoff_datetime | 2021-07-14 06:35:15
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 182
#  DOLocationID          | 182
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 2
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
#  Percents to next rate | 100.0%
# -RECORD 6---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-15 13:22:05
#  lpep_dropoff_datetime | 2021-07-15 13:59:07
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 80
#  DOLocationID          | 22
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
#  Percents to next rate | 100.0%
# -RECORD 7---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-19 09:42:33
#  lpep_dropoff_datetime | 2021-07-19 09:47:34
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 26
#  DOLocationID          | 178
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
#  Percents to next rate | 100.0%
# -RECORD 8---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-21 11:02:27
#  lpep_dropoff_datetime | 2021-07-21 11:08:50
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 47
#  DOLocationID          | 47
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
#  Percents to next rate | 100.0%
# -RECORD 9---------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-21 12:44:33
#  lpep_dropoff_datetime | 2021-07-21 12:55:39
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 45
#  DOLocationID          | 137
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
#  Percents to next rate | 100.0%
# -RECORD 10--------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-21 18:31:57
#  lpep_dropoff_datetime | 2021-07-21 18:31:58
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 85
#  DOLocationID          | 85
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
#  Percents to next rate | 100.0%
# -RECORD 11--------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-28 23:38:57
#  lpep_dropoff_datetime | 2021-07-28 23:46:45
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 102
#  DOLocationID          | 102
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 0.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.0
#  total_amount          | 0.0
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 0.0
#  payment_rate_rank     | 1
#  Next Payment Rate     | 7.429130009775171E-4
#  Max Payment Rate      | 39.55
#  Percents to next rate | 100.0%
# -RECORD 12--------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-14 08:42:47
#  lpep_dropoff_datetime | 2021-07-14 08:43:37
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 75
#  DOLocationID          | 74
#  passenger_count       | 1
#  trip_distance         | 0.3
#  fare_amount           | 3.0
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 3.8
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 7.429130009775171E-4
#  payment_rate_rank     | 13
#  Next Payment Rate     | 7.526881720430108E-4
#  Max Payment Rate      | 39.55
#  Percents to next rate | 1.3%
# -RECORD 13--------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-24 12:04:50
#  lpep_dropoff_datetime | 2021-07-24 12:05:04
#  store_and_fwd_flag    | Y
#  RatecodeID            | 1
#  PULocationID          | 145
#  DOLocationID          | 145
#  passenger_count       | 1
#  trip_distance         | 0.0
#  fare_amount           | 2.5
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.05
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 3.85
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 7.526881720430108E-4
#  payment_rate_rank     | 14
#  Next Payment Rate     | 8.406647116324536E-4
#  Max Payment Rate      | 39.55
#  Percents to next rate | 10.47%
# -RECORD 14--------------------------------------------
#  VendorID              | 1
#  payment_type          | 1
#  lpep_pickup_datetime  | 2021-07-16 07:17:15
#  lpep_dropoff_datetime | 2021-07-16 07:18:57
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 166
#  DOLocationID          | 166
#  passenger_count       | 1
#  trip_distance         | 0.5
#  fare_amount           | 3.5
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 4.3
#  trip_type             | 1
#  congestion_surcharge  | 0.0
#  Vendor                | Creative Mobile Technologies
#  Payment Type          | Credit card
#  PCPVP                 | 5115
#  Payment Rate          | 8.406647116324536E-4
#  payment_rate_rank     | 15
#  Next Payment Rate     | 8.895405669599218E-4
#  Max Payment Rate      | 39.55
#  Percents to next rate | 5.49%
# only showing top 15 rows

# %% [markdown]
# ### Select only required fields

# %%
report = report.select('Vendor', 'Payment Type', 'Payment Rate', 'Next Payment Rate', 'Max Payment Rate', 'Percents to next rate')

# %% [markdown]
# ### Save report to the CSV file

# %%
import glob
import os

destination = config['data']['destination']
report.coalesce(1).write.mode('overwrite').option('header', 'true').csv(destination)

list_of_files = glob.glob(f'{destination}/*.csv')
latest_csv_file = max(list_of_files, key=os.path.getctime)

# %% [markdown]
# ### Send report to the email

# %%
import smtplib, ssl
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders

def send_report(config, file):
    msg = MIMEMultipart()
    msg['Subject'] = config['subject'] 
    msg['From'] = config['user']
    msg['To'] = config['receiver']
    
    part = MIMEBase('application', "octet-stream")
    part.set_payload(open(file, "rb").read())
    encoders.encode_base64(part)

    part.add_header('Content-Disposition', 'attachment; filename="report.csv"')

    msg.attach(part)
    
    ssl_context = ssl.create_default_context()
    service = smtplib.SMTP_SSL(config['server'], config['port'], context=ssl_context)
    service.login(config['user'], config['password'])

    result = service.sendmail(config['user'], config['receiver'], msg.as_string())

    service.quit()
    

send_report(
    config['mail'],
    latest_csv_file
)
